# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'C:\Users\hamit\Desktop\Project4\Sales Transaction v.4a.csv')

# %%
df=pd.DataFrame(data)

# %%
df.head(20)
# Out:
#    TransactionNo       Date ProductNo                          ProductName  \
# 0         581482  12/9/2019     22485        Set Of 2 Wooden Market Crates
# 1         581475  12/9/2019     22596  Christmas Star Wish List Chalkboard
# 2         581475  12/9/2019     23235             Storage Tin Vintage Leaf
# 3         581475  12/9/2019     23272    Tree T-Light Holder Willie Winkie
# 4         581475  12/9/2019     23239    Set Of 4 Knick Knack Tins Poppies
# 5         581475  12/9/2019     21705              Bag 500g Swirly Marbles
# 6         581475  12/9/2019     22118             Joy Wooden Block Letters
# 7         581475  12/9/2019     22119           Peace Wooden Block Letters
# 8         581475  12/9/2019     22217          T-Light Holder Hanging Lace
# 9         581475  12/9/2019     22216            T-Light Holder White Lace
# 10        581475  12/9/2019     22380                    Toy Tidy Spaceboy
# ...

# %%
dateFormat = '%m/%d/%Y'
df['Date'] = pd.to_datetime(df['Date'],format = dateFormat)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536350 entries, 0 to 536349
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   TransactionNo  536350 non-null  object
#  1   Date           536350 non-null  datetime64[ns]
#  2   ProductNo      536350 non-null  object
#  3   ProductName    536350 non-null  object
#  4   Price          536350 non-null  float64
#  5   Quantity       536350 non-null  int64
#  6   CustomerNo     536295 non-null  float64
#  7   Country        536350 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.7+ MB

# %%
df.isnull().sum()
# Out:
# TransactionNo     0
# Date              0
# ProductNo         0
# ProductName       0
# Price             0
# Quantity          0
# CustomerNo       55
# Country           0
# dtype: int64

# %%
df['Total_price']= df['Quantity']*df['Price']

# %%
df
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482 2019-12-09     22485
# 1             581475 2019-12-09     22596
# 2             581475 2019-12-09     23235
# 3             581475 2019-12-09     23272
# 4             581475 2019-12-09     23239
# ...              ...        ...       ...
# 536345       C536548 2018-12-01     22168
# 536346       C536548 2018-12-01     21218
# 536347       C536548 2018-12-01     20957
# 536348       C536548 2018-12-01     22580
# 536349       C536548 2018-12-01     22767
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6     13069.0
# ...

# %%
# split data into effective sales and cancellation

# %%
df_positive=df.loc[df['Quantity']>0 ]
df_positive
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482 2019-12-09     22485
# 1             581475 2019-12-09     22596
# 2             581475 2019-12-09     23235
# 3             581475 2019-12-09     23272
# 4             581475 2019-12-09     23239
# ...              ...        ...       ...
# 536320        536585 2018-12-01     37449
# 536321        536590 2018-12-01     22776
# 536322        536590 2018-12-01     22622
# 536323        536591 2018-12-01     37449
# 536324        536597 2018-12-01     22220
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6     13069.0
# ...

# %%
sales= df_positive.to_csv(r'C:\Users\hamit\Desktop\Project4\sales_clean.csv')

# %%
df_negative=df.loc[df['Quantity']<0 ]
df_negative
# Out:
#        TransactionNo       Date ProductNo                       ProductName  \
# 1616         C581484 2019-12-09     23843         Paper Craft Little Birdie
# 1617         C581490 2019-12-09     22178   Victorian Glass Hanging T-Light
# 1618         C581490 2019-12-09     23144   Zinc T-Light Holder Stars Small
# 1619         C581568 2019-12-09     21258        Victorian Sewing Box Large
# 1620         C581569 2019-12-09     84978  Hanging Heart Jar T-Light Holder
# ...              ...        ...       ...                               ...
# 536345       C536548 2018-12-01     22168      Organiser Wood Antique White
# 536346       C536548 2018-12-01     21218            Red Spotty Biscuit Tin
# 536347       C536548 2018-12-01     20957      Porcelain Hanging Bell Small
# 536348       C536548 2018-12-01     22580      Advent Calendar Gingham Sack
# 536349       C536548 2018-12-01     22767        Triple Photo Frame Cornice
#
# ...

# %%
df_positive_local=df_positive.loc[df_positive['Country']=='United Kingdom']
df_positive_local
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482 2019-12-09     22485
# 1             581475 2019-12-09     22596
# 2             581475 2019-12-09     23235
# 3             581475 2019-12-09     23272
# 4             581475 2019-12-09     23239
# ...              ...        ...       ...
# 536320        536585 2018-12-01     37449
# 536321        536590 2018-12-01     22776
# 536322        536590 2018-12-01     22622
# 536323        536591 2018-12-01     37449
# 536324        536597 2018-12-01     22220
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6     13069.0
# ...

# %%
sales= df_positive_local.to_csv(r'C:\Users\hamit\Desktop\Project4\sales_local_clean.csv', index=False)

# %%
df_positive_foreign=df_positive.loc[df_positive['Country']!='United Kingdom']
df_positive_foreign
# Out:
#        TransactionNo       Date ProductNo                        ProductName  \
# 20            581476 2019-12-09     23198      Pantry Magnetic Shopping List
# 21            581476 2019-12-09     23197  Sketchbook Magnetic Shopping List
# 22            581476 2019-12-09     23184             Bull Dog Bottle Opener
# 23            581476 2019-12-09     23168       Classic Cafe Sugar Dispenser
# 24            581476 2019-12-09     23167      Small Ceramic Top Storage Jar
# ...              ...        ...       ...                                ...
# 534617        536540 2018-12-01     21889             Wooden Box Of Dominoes
# 534618        536540 2018-12-01     21891   Traditional Wooden Skipping Rope
# 534619        536541 2018-12-01     21915               Red Harmonica In Box
# 536310        536540 2018-12-01     22968          Rose Cottage Keepsake Box
# 536311        536540 2018-12-01     22622     Box Of Vintage Alphabet Blocks
#
# ...
